# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
import numpy as np
import mediapipe as mp
import os
import shutil
import matplotlib.pyplot as plt
import mediapipe as mp
 
mp_facemesh = mp.solutions.face_mesh
mp_drawing  = mp.solutions.drawing_utils
denormalize_coordinates = mp_drawing._normalized_to_pixel_coordinates
 
# %matplotlib inline

# %%
#os.makedirs('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/Fatigue Subjects')
#os.makedirs('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/Active Subjects')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19468\2889739971.py in <module>
# ----> 1 os.makedirs('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/Fatigue Subjects')
#       2 os.makedirs('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/Active Subjects')
#
# ~\miniforge3\envs\myenv\lib\os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:/Users/kang mingu/Desktop/dataset/0 FaceImages/Fatigue Subjects'

# %%
# Landmark points corresponding to left eye
all_left_eye_idxs = list(mp_facemesh.FACEMESH_LEFT_EYE)
# flatten and remove duplicates
all_left_eye_idxs = set(np.ravel(all_left_eye_idxs)) 
 
# Landmark points corresponding to right eye
all_right_eye_idxs = list(mp_facemesh.FACEMESH_RIGHT_EYE)
all_right_eye_idxs = set(np.ravel(all_right_eye_idxs))
 
# Combined for plotting - Landmark points for both eye
all_idxs = all_left_eye_idxs.union(all_right_eye_idxs)
 
# The chosen 12 points:   P1,  P2,  P3,  P4,  P5,  P6
chosen_left_eye_idxs  = [362, 385, 387, 263, 373, 380]
chosen_right_eye_idxs = [33,  160, 158, 133, 153, 144]
all_chosen_idxs = chosen_left_eye_idxs + chosen_right_eye_idxs

# %%
IMG_SIZE=145
i=0
def draw(
    *,n=i,
    img_dt,cat,
    img_eye_lmks=None,
    img_eye_lmks_chosen=None,
    face_landmarks=None,
    ts_thickness=1,
    ts_circle_radius=2,
    lmk_circle_radius=3,
    name="1",
):
    # For plotting Face Tessellation
    image_drawing_tool = img_dt 
     
     # For plotting all eye landmarks
    image_eye_lmks = img_dt.copy() if img_eye_lmks is None else img_eye_lmks
     
    # For plotting chosen eye landmarks
    img_eye_lmks_chosen = img_dt.copy() if img_eye_lmks_chosen is None else img_eye_lmks_chosen
 
    # Initializing drawing utilities for plotting face mesh tessellation
    connections_drawing_spec = mp_drawing.DrawingSpec(
        thickness=ts_thickness, 
        circle_radius=ts_circle_radius, 
        color=(255, 255, 255)
    )

 
    # Draw landmarks on face using the drawing utilities.
    mp_drawing.draw_landmarks(
        image=image_drawing_tool,
        landmark_list=face_landmarks,
        connections=mp_facemesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=connections_drawing_spec,
    )
 
    # Get the object which holds the x, y, and z coordinates for each landmark
    landmarks = face_landmarks.landmark
 
    # Iterate over all landmarks.
    # If the landmark_idx is present in either all_idxs or all_chosen_idxs,
    # get the denormalized coordinates and plot circles at those coordinates.
 
    for landmark_idx, landmark in enumerate(landmarks):
        if landmark_idx in all_idxs:
            pred_cord = denormalize_coordinates(landmark.x, 
                                                landmark.y, 
                                                imgW, imgH)
            cv2.circle(image_eye_lmks, 
                       pred_cord, 
                       lmk_circle_radius, 
                       (255, 255, 255), 
                       -1
                       )
 
        if landmark_idx in all_chosen_idxs:
            pred_cord = denormalize_coordinates(landmark.x, 
                                                landmark.y, 
                                                imgW, imgH)
            cv2.circle(img_eye_lmks_chosen, 
                       pred_cord, 
                       lmk_circle_radius, 
                       (255, 255, 255), 
                       -1
                       )
 
    if cat=='Fatigue Subjects':
        cv2.imwrite(str('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/Fatigue Subjects/'+str(n)+'.jpg'), image_drawing_tool)
    else:
        cv2.imwrite(str('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/Active Subjects/'+str(n)+'.jpg'), image_drawing_tool)

    resized_array = cv2.resize(image_drawing_tool, (IMG_SIZE, IMG_SIZE)) 
    return resized_array

# %%
imgH, imgW, _=0,0,0 
def landmarks(image,category,i):
    resized_array=[]
    IMG_SIZE = 145
    image = np.ascontiguousarray(image)
    imgH, imgW, _ = image.shape
                            
     # Running inference using static_image_mode 
    with mp_facemesh.FaceMesh(
        static_image_mode=True,         # Default=False
        max_num_faces=1,                # Default=1
        refine_landmarks=False,         # Default=False
        min_detection_confidence=0.5,   # Default=0.5
        min_tracking_confidence= 0.5,) as face_mesh:

        results = face_mesh.process(image)

        # If detections are available.
        if results.multi_face_landmarks:  
            for face_id, face_landmarks in enumerate(results.multi_face_landmarks):
                resized_array= draw(img_dt=image.copy(), cat=category, n=i,face_landmarks=face_landmarks)
    return resized_array

# %%
def face_for_yawn(direc="C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages", face_cas_path="C:/Users/kang mingu/haarcascade_frontalface_default.xml"):
    yaw_no=[]
    i=1
    IMG_SIZE = 145
    categories = ["Fatigue Subjects", "Active Subjects"]
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            face_cascade = cv2.CascadeClassifier(face_cas_path)
            faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
            for (x, y, w, h) in faces:
                img = cv2.rectangle(image_array, (x, y), (x+w, y+h), (0, 255, 0), 2)
                roi_color = img[y:y+h, x:x+w]
                land_face_array=landmarks(roi_color,category,i)
                yaw_no.append([land_face_array, class_num1])
                i=i+1
    return yaw_no
yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1

# %%
dir_path = r'C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/Active Subjects'
print("Number of Active images :")
print(len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))]))
# Out:
# Number of Active images :
# 9566

# %%
dir_path = r'C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/Fatigue Subjects'
print("Number of Fatigue images :")
print(len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))]))
# Out:
# Number of Fatigue images :
# 8804

# %%
categories = ["Fatigue Subjects", "Active Subjects"]
for category in categories:
  for idx, img in enumerate(os.listdir(f'C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/{category}')):
      if idx > 5:
        break
      img_file = cv2.imread(f'C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/{category}/{img}')
      plt.imshow(img_file)
      plt.show()
      plt.close()

# %%
import os
import time
def face_for_yawn(direc="C:/Users/kang mingu/Desktop/dataset/0 FaceImages/0 FaceImages/"):
    yaw_no=[]
    i=1
    IMG_SIZE = 145
    categories = ["Fatigue Subjects", "Active Subjects"]
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            resized_array = cv2.resize(image_array, (IMG_SIZE, IMG_SIZE))
            yaw_no.append([resized_array, class_num1])
                #print('image face number '+str(i))
                #i=i+1
    return yaw_no
yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1

# %%
X = []
y = []
for feature, label in yawn_no_yawn:
    X.append(feature)
    y.append(label)

# %%
X = np.array(X)
X = X.reshape(-1, 145, 145, 3)

# %%
from sklearn.preprocessing import LabelEncoder
label_bin = LabelEncoder()
y = label_bin.fit_transform(y)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import os
import cv2
seed = 42
test_size = 0.20
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, test_size=test_size)

# %%
len(X_test)
# Out:
# 3674

# %%
len(X_train)
# Out:
# 14696

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# %%
# 데이터 제너레이터 생성
batch_size = 64

train_datagen = ImageDataGenerator(
    rescale=1/255,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)

test_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size, shuffle=False)
test_generator = test_datagen.flow(X_test, y_test, batch_size=batch_size, shuffle=False)

# %%
# Model Elsafty 1
from keras.layers import BatchNormalization
model = tf.keras.models.Sequential()
# Note the input shape is the desired size of the image 145 x 145 with 3 bytes color
# This is the first convolution
model.add(Conv2D(16, 3, activation='relu', input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D())
tf.keras.layers.Dropout(0.1)
# The second convolution
model.add(Conv2D(32, 5, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
tf.keras.layers.Dropout(0.1)
# The third convolution
model.add(Conv2D(64, 10, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
tf.keras.layers.Dropout(0.1)
# The fourth convolution
model.add(Conv2D(128, 12, activation='relu'))
model.add(BatchNormalization())

# Flatten the results to feed into a DNN
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(64, activation='relu'))
# Only 1 output neuron.
model.add(Dense(1, activation='sigmoid'))
model.compile(loss="binary_crossentropy", metrics=["accuracy"], optimizer="adam")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 143, 143, 16)      448
#
#  batch_normalization (BatchN  (None, 143, 143, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 71, 71, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 67, 67, 32)        12832
#
#  batch_normalization_1 (Batc  (None, 67, 67, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 33, 33, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        204864
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 128)         1179776
#
#  batch_normalization_3 (Batc  (None, 1, 1, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,423,713
# Trainable params: 1,423,233
# Non-trainable params: 480
# _________________________________________________________________

# %%
history = model.fit(train_generator, epochs=70, validation_data=test_generator)
# Out:
# Epoch 1/70
# 460/460 [==============================] - 48s 96ms/step - loss: 0.4962 - accuracy: 0.7509 - val_loss: 0.4378 - val_accuracy: 0.7803
# Epoch 2/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.4206 - accuracy: 0.7910 - val_loss: 0.4632 - val_accuracy: 0.7703
# Epoch 3/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.3681 - accuracy: 0.8212 - val_loss: 0.3593 - val_accuracy: 0.8193
# Epoch 4/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.3296 - accuracy: 0.8469 - val_loss: 0.3322 - val_accuracy: 0.8408
# Epoch 5/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.3115 - accuracy: 0.8544 - val_loss: 0.2985 - val_accuracy: 0.8664
# Epoch 6/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.3004 - accuracy: 0.8623 - val_loss: 0.3175 - val_accuracy: 0.8552
# Epoch 7/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2932 - accuracy: 0.8668 - val_loss: 0.2860 - val_accuracy: 0.8683
# Epoch 8/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.2790 - accuracy: 0.8734 - val_loss: 0.3471 - val_accuracy: 0.8508
# Epoch 9/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2760 - accuracy: 0.8776 - val_loss: 0.3040 - val_accuracy: 0.8601
# Epoch 10/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2615 - accuracy: 0.8827 - val_loss: 0.2640 - val_accuracy: 0.8862
# Epoch 11/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.2625 - accuracy: 0.8839 - val_loss: 0.3159 - val_accuracy: 0.8628
# Epoch 12/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.2578 - accuracy: 0.8853 - val_loss: 0.3272 - val_accuracy: 0.8552
# Epoch 13/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2493 - accuracy: 0.8896 - val_loss: 0.2926 - val_accuracy: 0.8696
# Epoch 14/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.2456 - accuracy: 0.8918 - val_loss: 0.2641 - val_accuracy: 0.8762
# Epoch 15/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.2347 - accuracy: 0.8958 - val_loss: 0.2977 - val_accuracy: 0.8519
# Epoch 16/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.2320 - accuracy: 0.8990 - val_loss: 0.2494 - val_accuracy: 0.8851
# Epoch 17/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2313 - accuracy: 0.8983 - val_loss: 0.2620 - val_accuracy: 0.8889
# Epoch 18/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2197 - accuracy: 0.9056 - val_loss: 0.2607 - val_accuracy: 0.8835
# Epoch 19/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2212 - accuracy: 0.9036 - val_loss: 0.2865 - val_accuracy: 0.8658
# Epoch 20/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2153 - accuracy: 0.9085 - val_loss: 0.2346 - val_accuracy: 0.8996
# Epoch 21/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2078 - accuracy: 0.9111 - val_loss: 0.2453 - val_accuracy: 0.8906
# Epoch 22/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.2087 - accuracy: 0.9102 - val_loss: 0.2374 - val_accuracy: 0.8987
# Epoch 23/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1992 - accuracy: 0.9156 - val_loss: 0.2336 - val_accuracy: 0.9039
# Epoch 24/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1945 - accuracy: 0.9183 - val_loss: 0.2418 - val_accuracy: 0.8971
# Epoch 25/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1910 - accuracy: 0.9175 - val_loss: 0.2583 - val_accuracy: 0.8849
# Epoch 26/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1907 - accuracy: 0.9209 - val_loss: 0.1936 - val_accuracy: 0.9200
# Epoch 27/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1856 - accuracy: 0.9219 - val_loss: 0.2326 - val_accuracy: 0.8933
# Epoch 28/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1819 - accuracy: 0.9210 - val_loss: 0.1949 - val_accuracy: 0.9303
# Epoch 29/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1756 - accuracy: 0.9280 - val_loss: 0.2494 - val_accuracy: 0.8941
# Epoch 30/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1835 - accuracy: 0.9260 - val_loss: 0.2055 - val_accuracy: 0.9249
# Epoch 31/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1713 - accuracy: 0.9308 - val_loss: 0.2562 - val_accuracy: 0.8930
# Epoch 32/70
# 460/460 [==============================] - 43s 94ms/step - loss: 0.1739 - accuracy: 0.9269 - val_loss: 0.1869 - val_accuracy: 0.9208
# Epoch 33/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1701 - accuracy: 0.9283 - val_loss: 0.1992 - val_accuracy: 0.9227
# Epoch 34/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1632 - accuracy: 0.9308 - val_loss: 0.2575 - val_accuracy: 0.8949
# Epoch 35/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1573 - accuracy: 0.9353 - val_loss: 0.2527 - val_accuracy: 0.8974
# Epoch 36/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1621 - accuracy: 0.9330 - val_loss: 0.2380 - val_accuracy: 0.9039
# Epoch 37/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1551 - accuracy: 0.9367 - val_loss: 0.2143 - val_accuracy: 0.9140
# Epoch 38/70
# 460/460 [==============================] - 43s 94ms/step - loss: 0.1543 - accuracy: 0.9358 - val_loss: 0.2236 - val_accuracy: 0.9181
# Epoch 39/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1534 - accuracy: 0.9376 - val_loss: 0.2246 - val_accuracy: 0.9110
# Epoch 40/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1513 - accuracy: 0.9368 - val_loss: 0.2173 - val_accuracy: 0.9137
# Epoch 41/70
# 460/460 [==============================] - 43s 94ms/step - loss: 0.1492 - accuracy: 0.9390 - val_loss: 0.2521 - val_accuracy: 0.9066
# Epoch 42/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1477 - accuracy: 0.9395 - val_loss: 0.1856 - val_accuracy: 0.9249
# Epoch 43/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1454 - accuracy: 0.9386 - val_loss: 0.2736 - val_accuracy: 0.9017
# Epoch 44/70
# 460/460 [==============================] - 43s 94ms/step - loss: 0.1403 - accuracy: 0.9431 - val_loss: 0.2700 - val_accuracy: 0.9012
# Epoch 45/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1415 - accuracy: 0.9432 - val_loss: 0.3697 - val_accuracy: 0.8587
# Epoch 46/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1367 - accuracy: 0.9437 - val_loss: 0.2567 - val_accuracy: 0.9047
# Epoch 47/70
# 460/460 [==============================] - 44s 95ms/step - loss: 0.1369 - accuracy: 0.9452 - val_loss: 0.1862 - val_accuracy: 0.9303
# Epoch 48/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1323 - accuracy: 0.9456 - val_loss: 0.2031 - val_accuracy: 0.9208
# Epoch 49/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1359 - accuracy: 0.9472 - val_loss: 0.2923 - val_accuracy: 0.8936
# Epoch 50/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1257 - accuracy: 0.9496 - val_loss: 0.2027 - val_accuracy: 0.9200
# Epoch 51/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1331 - accuracy: 0.9488 - val_loss: 0.3012 - val_accuracy: 0.8775
# Epoch 52/70
# 460/460 [==============================] - 45s 99ms/step - loss: 0.1285 - accuracy: 0.9493 - val_loss: 0.1801 - val_accuracy: 0.9393
# Epoch 53/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1253 - accuracy: 0.9496 - val_loss: 0.2914 - val_accuracy: 0.8938
# Epoch 54/70
# 460/460 [==============================] - 44s 96ms/step - loss: 0.1223 - accuracy: 0.9513 - val_loss: 0.2236 - val_accuracy: 0.9132
# Epoch 55/70
# 460/460 [==============================] - 45s 97ms/step - loss: 0.1365 - accuracy: 0.9451 - val_loss: 0.2866 - val_accuracy: 0.8857
# Epoch 56/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1222 - accuracy: 0.9499 - val_loss: 0.1805 - val_accuracy: 0.9390
# Epoch 57/70
# 460/460 [==============================] - 45s 98ms/step - loss: 0.1243 - accuracy: 0.9505 - val_loss: 0.1970 - val_accuracy: 0.9265
# Epoch 58/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1221 - accuracy: 0.9526 - val_loss: 0.3027 - val_accuracy: 0.8881
# Epoch 59/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1200 - accuracy: 0.9508 - val_loss: 0.2208 - val_accuracy: 0.9085
# Epoch 60/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1156 - accuracy: 0.9530 - val_loss: 0.2549 - val_accuracy: 0.9129
# Epoch 61/70
# 460/460 [==============================] - 45s 99ms/step - loss: 0.1195 - accuracy: 0.9523 - val_loss: 0.1833 - val_accuracy: 0.9311
# Epoch 62/70
# 460/460 [==============================] - 45s 99ms/step - loss: 0.1202 - accuracy: 0.9513 - val_loss: 0.2249 - val_accuracy: 0.9200
# Epoch 63/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1191 - accuracy: 0.9537 - val_loss: 0.1952 - val_accuracy: 0.9303
# Epoch 64/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1194 - accuracy: 0.9528 - val_loss: 0.2167 - val_accuracy: 0.9085
# Epoch 65/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1090 - accuracy: 0.9568 - val_loss: 0.1896 - val_accuracy: 0.9341
# Epoch 66/70
# 460/460 [==============================] - 46s 100ms/step - loss: 0.1114 - accuracy: 0.9589 - val_loss: 0.2362 - val_accuracy: 0.9113
# Epoch 67/70
# 460/460 [==============================] - 46s 99ms/step - loss: 0.1131 - accuracy: 0.9528 - val_loss: 0.1861 - val_accuracy: 0.9358
# Epoch 68/70
# 460/460 [==============================] - 47s 101ms/step - loss: 0.1076 - accuracy: 0.9567 - val_loss: 0.1836 - val_accuracy: 0.9388
# Epoch 69/70
# 460/460 [==============================] - 46s 101ms/step - loss: 0.1070 - accuracy: 0.9573 - val_loss: 0.1666 - val_accuracy: 0.9420
# Epoch 70/70
# 460/460 [==============================] - 46s 101ms/step - loss: 0.1023 - accuracy: 0.9587 - val_loss: 0.1901 - val_accuracy: 0.9311

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="trainning accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show()

plt.plot(epochs, loss, "b", label="trainning loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# %%
# You can evaluate or predict on a dataset.
print("Evaluate")
result = model.evaluate(test_generator)
dict(zip(model.metrics_names, result))
# Out:
# Evaluate
# 115/115 [==============================] - 1s 8ms/step - loss: 0.1901 - accuracy: 0.9311
# {'loss': 0.19008894264698029, 'accuracy': 0.93113774061203}

# %%
model.save('C:/Users/kang mingu/Desktop/dataset/0 FaceImages/my_model2.h5')
#model = tf.keras.models.load_model('my_model.h5')
